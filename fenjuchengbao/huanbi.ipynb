# %%
import pandas as pd
import numpy as np

import tkinter as tk
from tkinter import filedialog

# %%
print('正在打开……')
df_mr=pd.DataFrame()
root = tk.Tk()
root.withdraw()
# path = filedialog.askopenfilename()
# path_out, temp = os.path.split(path)
# file_name, extension = os.path.splitext(temp)
# print('path:', path_out)
# print('file_name:', file_name)
# print('extension:', extension)

path = filedialog.askopenfilename()
# Out:
# 正在打开……

# %%
df=pd.read_excel(path,sheet_name='Sheet3',skiprows=2,parse_dates=['Unnamed: 0'],index_col='Unnamed: 0')

# %%
df
# Out:
#         Unnamed: 1         目标值         完成值       完成率  类型得分         得分  \
# 202203     1277402  313.520000  295.364529  0.942092    20  17.104575
# 202203     1391551  299.570000  294.627550  0.983502    20  19.175076
# 202203     1277400  493.750000  500.191239  1.013046    20  20.652277
# 202203     1589617  256.760000  315.345470  1.228172    20  31.408605
# 202203     1277405  306.480000  315.521133  1.029500    20  21.474996
# ...            ...         ...         ...       ...   ...        ...
# 202204     1670397  346.191202  387.271652  1.118664    20  25.933203
# 202204     1670401  259.876822  310.341282  1.194186    20  29.709304
# 202204     1670398  179.947121  195.053688  1.083950    20  24.197502
# 202204     1670399  508.967635  522.530624  1.026648    20  21.332402
# 202204     1670441  331.486284  346.599273  1.045592    20  22.279580
#
#         修正得分(无上限，规则：得分*5/6,超出类型得分，则得分*5/6+得分-类型得分)   去年12月份额      当月份额  \
# ...

# %%
df_res=df.pct_change(periods=143)

# %%
df_res
# Out:
#         Unnamed: 1       目标值       完成值       完成率  类型得分        得分  \
# 202203         NaN       NaN       NaN       NaN   NaN       NaN
# 202203         NaN       NaN       NaN       NaN   NaN       NaN
# 202203         NaN       NaN       NaN       NaN   NaN       NaN
# 202203         NaN       NaN       NaN       NaN   NaN       NaN
# 202203         NaN       NaN       NaN       NaN   NaN       NaN
# ...            ...       ...       ...       ...   ...       ...
# 202204         0.0  2.896356  3.414313  0.132934   0.0  0.338817
# 202204         0.0  2.860895  3.346843  0.125864   0.0  0.289791
# 202204         0.0  2.877335  3.032019  0.039894   0.0  0.094005
# 202204         0.0  2.889703  2.875106 -0.003753   0.0 -0.008983
# 202204         0.0  2.922450  2.939414  0.004325   0.0  0.010208
#
#         修正得分(无上限，规则：得分*5/6,超出类型得分，则得分*5/6+得分-类型得分)   去年12月份额      当月份额  \
# 202203                                         NaN       NaN       NaN
# ...

# %%
lindex=path.rfind('/')

# %%
out_path=path[0:lindex+1]+'环比结果.xlsx'

# %%
df_res.to_excel(out_path)
